# %% [markdown]
# ## Stock Market Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# If we have a special type of file format
import glob

# %%
import warnings
from warnings import filterwarnings
filterwarnings('ignore')

# %%
#Loading Data
company = glob.glob(r'/Users/shyamgoyal/Desktop/UCI/Python Projects/Project 2/individual_stocks_5yr/*csv')

# %%
len(company)
# Out:
# 509

# %%
#Collecting Data
all_df = pd.DataFrame()

for file in company:
    current_df = pd.read_csv(file)
    all_df = current_df.append(all_df)
    #full_df = pd.concat([full_df, current_df], ignore_index=True)

# %%
all_df.shape
# Out:
# (624076, 7)

# %%
all_df.head(10)
# Out:
#          date   open   high    low  close    volume Name
# 0  2013-02-08  13.10  13.16  13.05  13.10  18596061    F
# 1  2013-02-11  13.06  13.20  13.02  13.11  17685616    F
# 2  2013-02-12  13.12  13.20  13.05  13.08  26231279    F
# 3  2013-02-13  13.11  13.14  12.99  13.04  24501066    F
# 4  2013-02-14  13.00  13.17  12.96  13.11  33487476    F
# 5  2013-02-15  13.14  13.14  13.01  13.02  32438244    F
# 6  2013-02-19  13.04  13.09  12.90  12.99  31088822    F
# 7  2013-02-20  12.95  12.98  12.57  12.60  50348019    F
# 8  2013-02-21  12.51  12.51  12.30  12.39  43703152    F
# 9  2013-02-22  12.44  12.50  12.31  12.48  23866354    F

# %%
all_df['Name'].unique()
# Out:
# array(['F', 'COG', 'COF', 'TWX', 'QCOM', 'WFC', 'WYN', 'WY', 'SJM',
#        'CERN', 'HAL', 'NKE', 'T', 'HCP', 'ORLY', 'ARE', 'MO', 'HPE',
#        'AAP', 'MAR', 'OXY', 'MAS', 'SYY', 'MCO', 'ABBV', 'ZION', 'FAST',
#        'FOX', 'JBHT', 'CA', 'SYMC', 'NBL', 'RCL', 'NCLH', 'CBG', 'JCI',
#        'AMZN', 'COL', 'URI', 'PBCT', 'HOLX', 'BMY', 'WBA', 'ABT', 'L',
#        'M', 'NWL', 'DTE', 'HBI', 'CHK', 'MGM', 'AGN', 'CAH', 'YUM', 'PFE',
#        'AES', 'STX', 'KIM', 'IPG', 'FTV', 'MCD', 'DG', 'PAYX', 'GILD',
#        'BLK', 'HRS', 'TSS', 'RTN', 'NWS', 'TSCO', 'MLM', 'IR', 'LEG',
#        'KO', 'HII', 'XLNX', 'VNO', 'ETR', 'DISCK', 'DPS', 'NDAQ', 'AWK',
#        'FTI', 'ETFC', 'WHR', 'FE', 'ROK', 'HRL', 'PDCO', 'WYNN', 'HPQ',
#        'CXO', 'BSX', 'GOOGL', 'ROST', 'MYL', 'JEC', 'AMAT', 'WM', 'PXD',
#        'BF.B', 'AVY', 'IDXX', 'XOM', 'WLTW', 'PWR', 'REG', 'DXC', 'LH',
#        'DRE', 'EXPD', 'EXPE', 'FIS', 'DISCA', 'VAR', 'TGT', 'LUV', 'SYF',
# ...

# %% [markdown]
# ### What was the change in price of the stock over time !!

# %%
company
# Out:
# ['/Users/shyamgoyal/Desktop/UCI/Python Projects/Project 2/individual_stocks_5yr/XRX_data.csv',
#  '/Users/shyamgoyal/Desktop/UCI/Python Projects/Project 2/individual_stocks_5yr/GS_data.csv',
#  '/Users/shyamgoyal/Desktop/UCI/Python Projects/Project 2/individual_stocks_5yr/SPGI_data.csv',
#  '/Users/shyamgoyal/Desktop/UCI/Python Projects/Project 2/individual_stocks_5yr/MTB_data.csv',
#  '/Users/shyamgoyal/Desktop/UCI/Python Projects/Project 2/individual_stocks_5yr/V_data.csv',
#  '/Users/shyamgoyal/Desktop/UCI/Python Projects/Project 2/individual_stocks_5yr/CTAS_data.csv',
#  '/Users/shyamgoyal/Desktop/UCI/Python Projects/Project 2/individual_stocks_5yr/ESRX_data.csv',
#  '/Users/shyamgoyal/Desktop/UCI/Python Projects/Project 2/individual_stocks_5yr/APH_data.csv',
#  '/Users/shyamgoyal/Desktop/UCI/Python Projects/Project 2/individual_stocks_5yr/BBT_data.csv',
#  '/Users/shyamgoyal/Desktop/UCI/Python Projects/Project 2/individual_stocks_5yr/RHI_data.csv',
# ...

# %%
company_list = [
    '/Users/shyamgoyal/Desktop/UCI/Python Projects/Project 2/individual_stocks_5yr/AAPL_data.csv',
 '/Users/shyamgoyal/Desktop/UCI/Python Projects/Project 2/individual_stocks_5yr/AMZN_data.csv',
 '/Users/shyamgoyal/Desktop/UCI/Python Projects/Project 2/individual_stocks_5yr/GOOG_data.csv',
 '/Users/shyamgoyal/Desktop/UCI/Python Projects/Project 2/individual_stocks_5yr/MSFT_data.csv',
]

# %%
#Collecting Data
few_df = pd.DataFrame()

for file in company_list:
    current_df = pd.read_csv(file)
    few_df = current_df.append(few_df)
    #full_df = pd.concat([full_df, current_df], ignore_index=True)

# %%
few_df['Name'].unique()
# Out:
# array(['MSFT', 'GOOG', 'AMZN', 'AAPL'], dtype=object)

# %%
# Check missing values

few_df.isnull().sum()
# Out:
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64

# %%
few_df.dtypes
# Out:
# date       object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# Name       object
# dtype: object

# %%
#Change the date column into Datetime format
few_df['date'] = pd.to_datetime(few_df['date'])

# %%
few_df
# Out:
#            date     open    high       low   close    volume  Name
# 0    2013-02-08   27.350   27.71   27.3100   27.55  33318306  MSFT
# 1    2013-02-11   27.650   27.92   27.5000   27.86  32247549  MSFT
# 2    2013-02-12   27.880   28.00   27.7500   27.88  35990829  MSFT
# 3    2013-02-13   27.930   28.11   27.8800   28.03  41715530  MSFT
# 4    2013-02-14   27.920   28.06   27.8700   28.04  32663174  MSFT
# ...         ...      ...     ...       ...     ...       ...   ...
# 1254 2018-02-01  167.165  168.62  166.7600  167.78  47230787  AAPL
# 1255 2018-02-02  166.000  166.80  160.1000  160.50  86593825  AAPL
# 1256 2018-02-05  159.100  163.88  156.0000  156.49  72738522  AAPL
# 1257 2018-02-06  154.830  163.72  154.0000  163.03  68243838  AAPL
# 1258 2018-02-07  163.085  163.40  159.0685  159.54  51608580  AAPL
#
# [4752 rows x 7 columns]

# %%
#Now We will create the 2*2 plot
tech_list = few_df['Name'].unique()

# %%
tech_list
# Out:
# array(['MSFT', 'GOOG', 'AMZN', 'AAPL'], dtype=object)

# %%
plt.figure(figsize=(20,12))

for index, company in enumerate(tech_list,1):
    plt.subplot(2,2,index)
    filter1 = few_df['Name']==company
    df = few_df[filter1]
    plt.plot(df['date'],df['close'])
    plt.title(company)

# %% [markdown]
# ### What is the moving average of the various stock!!

# %%
all_df['close'].rolling(window=10).mean().head(15)
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9     12.892
# 10    12.795
# 11    12.718
# 12    12.686
# 13    12.643
# 14    12.593
# Name: close, dtype: float64

# %%
# To make the manipulations on the new dataframe
new_df = all_df.copy()

# %%
# To get the Moving Average for 10, 20 and 50 entries
ma_day = [10,20,50]

for ma in ma_day:
    new_df['close_'+str(ma)] = new_df['close'].rolling(ma).mean()

# %%
new_df.shape
# Out:
# (624076, 10)

# %%
# To draw the Pandas time series plot, we have to change the index to Date column
new_df.set_index('date', inplace= True)

# %%
new_df
# Out:
#              open    high     low  close    volume Name  close_10  close_20  \
# date
# 2013-02-08  13.10  13.160  13.050  13.10  18596061    F       NaN       NaN
# 2013-02-11  13.06  13.200  13.020  13.11  17685616    F       NaN       NaN
# 2013-02-12  13.12  13.200  13.050  13.08  26231279    F       NaN       NaN
# 2013-02-13  13.11  13.140  12.990  13.04  24501066    F       NaN       NaN
# 2013-02-14  13.00  13.170  12.960  13.11  33487476    F       NaN       NaN
# ...           ...     ...     ...    ...       ...  ...       ...       ...
# 2018-02-01  34.10  34.330  32.560  32.75   8154921  XRX    32.699   31.8830
# 2018-02-02  32.51  32.510  31.535  31.63   3526028  XRX    32.682   31.9800
# 2018-02-05  31.80  32.680  31.380  31.38   4104575  XRX    32.556   32.0535
# 2018-02-06  30.94  31.530  30.220  30.85   4431244  XRX    32.383   32.0830
# 2018-02-07  30.73  31.405  30.730  31.18   2983504  XRX    32.265   32.1325
#
#             close_50
# date
# ...

# %%
new_df.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'volume', 'Name', 'close_10',
#        'close_20', 'close_50'],
#       dtype='object')

# %%
#Using Pandas Line Plot
plt.figure(figsize=(20,12))

for index , company in enumerate(tech_list , 1):
    plt.subplot(2 , 2 , index)
    filter1 = new_df['Name']==company
    df = new_df[filter1]
    df[['close_10','close_20', 'close_50']].plot(ax=plt.gca())
    plt.title(company)

# %% [markdown]
# ### Analyse Closing price change in apple stock

# %%
apple = pd.read_csv(r'/Users/shyamgoyal/Desktop/UCI/Python Projects/Project 2/individual_stocks_5yr/AAPL_data.csv')

# %%
apple.head(5)
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
# Percentage Change 
apple["Daily Return(in %)"] = apple['close'].pct_change()*100

# %%
apple
# Out:
#             date      open      high       low     close     volume  Name  \
# 0     2013-02-08   67.7142   68.4014   66.8928   67.8542  158168416  AAPL
# 1     2013-02-11   68.0714   69.2771   67.6071   68.5614  129029425  AAPL
# 2     2013-02-12   68.5014   68.9114   66.8205   66.8428  151829363  AAPL
# 3     2013-02-13   66.7442   67.6628   66.1742   66.7156  118721995  AAPL
# 4     2013-02-14   66.3599   67.3771   66.2885   66.6556   88809154  AAPL
# ...          ...       ...       ...       ...       ...        ...   ...
# 1254  2018-02-01  167.1650  168.6200  166.7600  167.7800   47230787  AAPL
# 1255  2018-02-02  166.0000  166.8000  160.1000  160.5000   86593825  AAPL
# 1256  2018-02-05  159.1000  163.8800  156.0000  156.4900   72738522  AAPL
# 1257  2018-02-06  154.8300  163.7200  154.0000  163.0300   68243838  AAPL
# 1258  2018-02-07  163.0850  163.4000  159.0685  159.5400   51608580  AAPL
#
#       Daily Return(in %)
# 0                    NaN
# 1               1.042235
# ...

# %%
import plotly.express as px

# %%
px.line(apple, x= 'date',y='Daily Return(in %)')
# Out:
# <div>                            <div id="766b770b-cab3-45fb-876a-064eabff7852" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("766b770b-cab3-45fb-876a-064eabff7852")) {                    Plotly.newPlot(                        "766b770b-cab3-45fb-876a-064eabff7852",                        [{"hovertemplate":"date=%{x}\u003cbr\u003eDaily Return(in %)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-02-08","2013-02-11","2013-02-12","2013-02-13","2013-02-14","2013-02-15","2013-02-19","2013-02-20","2013-02-21","2013-02-22","2013-02-25","2013-02-26","2013-02-27","2013-02-28","2013-03-01","2013-03-04","2013-03-05","20
# ...

# %% [markdown]
# ### Performing resampling analysis of closing price

# %%
apple.dtypes
# Out:
# date                   object
# open                  float64
# high                  float64
# low                   float64
# close                 float64
# volume                  int64
# Name                   object
# Daily Return(in %)    float64
# dtype: object

# %%
apple['date'] = pd.to_datetime(apple['date'])

# %%
apple.dtypes
# Out:
# date                  datetime64[ns]
# open                         float64
# high                         float64
# low                          float64
# close                        float64
# volume                         int64
# Name                          object
# Daily Return(in %)           float64
# dtype: object

# %%
# To draw the Pandas time series plot, we have to change the index to Date column
apple.set_index('date', inplace= True)

# %%
apple
# Out:
#                 open      high       low     close     volume  Name  \
# date
# 2013-02-08   67.7142   68.4014   66.8928   67.8542  158168416  AAPL
# 2013-02-11   68.0714   69.2771   67.6071   68.5614  129029425  AAPL
# 2013-02-12   68.5014   68.9114   66.8205   66.8428  151829363  AAPL
# 2013-02-13   66.7442   67.6628   66.1742   66.7156  118721995  AAPL
# 2013-02-14   66.3599   67.3771   66.2885   66.6556   88809154  AAPL
# ...              ...       ...       ...       ...        ...   ...
# 2018-02-01  167.1650  168.6200  166.7600  167.7800   47230787  AAPL
# 2018-02-02  166.0000  166.8000  160.1000  160.5000   86593825  AAPL
# 2018-02-05  159.1000  163.8800  156.0000  156.4900   72738522  AAPL
# 2018-02-06  154.8300  163.7200  154.0000  163.0300   68243838  AAPL
# 2018-02-07  163.0850  163.4000  159.0685  159.5400   51608580  AAPL
#
#             Daily Return(in %)
# date
# 2013-02-08                 NaN
# 2013-02-11            1.042235
# 2013-02-12           -2.506658
# ...

# %%
#Resampling to Monthly data
apple['close'].resample('M').mean()
# Out:
# date
# 2013-02-28     65.306264
# 2013-03-31     63.120110
# 2013-04-30     59.966432
# 2013-05-31     63.778927
# 2013-06-30     60.791120
#                  ...
# 2017-10-31    157.817273
# 2017-11-30    172.406190
# 2017-12-31    171.891500
# 2018-01-31    174.005238
# 2018-02-28    161.468000
# Freq: M, Name: close, Length: 61, dtype: float64

# %%
apple['close'].resample('M').mean().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
apple['close'].resample('Y').mean()
# Out:
# date
# 2013-12-31     67.237839
# 2014-12-31     92.264531
# 2015-12-31    120.039861
# 2016-12-31    104.604008
# 2017-12-31    150.585080
# 2018-12-31    171.594231
# Freq: A-DEC, Name: close, dtype: float64

# %%
apple['close'].resample('Y').mean().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
apple['close'].resample('Q').mean().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ###  Correlation Analysis
# Checking if the closing price of these tech companies(Amazon, Apple, Google, Microosft) are correlated or not

# %%
company_list
# Out:
# ['/Users/shyamgoyal/Desktop/UCI/Python Projects/Project 2/individual_stocks_5yr/AAPL_data.csv',
#  '/Users/shyamgoyal/Desktop/UCI/Python Projects/Project 2/individual_stocks_5yr/AMZN_data.csv',
#  '/Users/shyamgoyal/Desktop/UCI/Python Projects/Project 2/individual_stocks_5yr/GOOG_data.csv',
#  '/Users/shyamgoyal/Desktop/UCI/Python Projects/Project 2/individual_stocks_5yr/MSFT_data.csv']

# %%
app = pd.read_csv(company_list[0])
amzn = pd.read_csv(company_list[1])
google = pd.read_csv(company_list[2])
msft = pd.read_csv(company_list[3])

# %%
# Creaitng an empty DataFrmae
closing_price = pd.DataFrame()

# %%
closing_price['apple_close'] = app['close']
closing_price['amazon_close'] = amzn['close']
closing_price['google_close'] = google['close']
closing_price['msft_close'] = msft['close']

# %%
closing_price
# Out:
#       apple_close  amazon_close  google_close  msft_close
# 0         67.8542        261.95        558.46       27.55
# 1         68.5614        257.21        559.99       27.86
# 2         66.8428        258.70        556.97       27.88
# 3         66.7156        269.47        567.16       28.03
# 4         66.6556        269.24        567.00       28.04
# ...           ...           ...           ...         ...
# 1254     167.7800       1390.00           NaN       94.26
# 1255     160.5000       1429.95           NaN       91.78
# 1256     156.4900       1390.00           NaN       88.00
# 1257     163.0300       1442.84           NaN       91.33
# 1258     159.5400       1416.78           NaN       89.61
#
# [1259 rows x 4 columns]

# %%
sns.pairplot(closing_price)

# %%
closing_price.corr()
# Out:
#               apple_close  amazon_close  google_close  msft_close
# apple_close      1.000000      0.819078      0.640522    0.899689
# amazon_close     0.819078      1.000000      0.888456    0.955977
# google_close     0.640522      0.888456      1.000000    0.907011
# msft_close       0.899689      0.955977      0.907011    1.000000

# %%
sns.heatmap(closing_price.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Analyse whether Daily change in Closing price of stock or Daily Return in stock are co-related or not!

# %%
# Kernal Density Estimation

# %%
closing_price
# Out:
#       apple_close  amazon_close  google_close  msft_close
# 0         67.8542        261.95        558.46       27.55
# 1         68.5614        257.21        559.99       27.86
# 2         66.8428        258.70        556.97       27.88
# 3         66.7156        269.47        567.16       28.03
# 4         66.6556        269.24        567.00       28.04
# ...           ...           ...           ...         ...
# 1254     167.7800       1390.00           NaN       94.26
# 1255     160.5000       1429.95           NaN       91.78
# 1256     156.4900       1390.00           NaN       88.00
# 1257     163.0300       1442.84           NaN       91.33
# 1258     159.5400       1416.78           NaN       89.61
#
# [1259 rows x 4 columns]

# %%
closing_price['apple_close'].shift(1)
# Out:
# 0            NaN
# 1        67.8542
# 2        68.5614
# 3        66.8428
# 4        66.7156
#           ...
# 1254    167.4300
# 1255    167.7800
# 1256    160.5000
# 1257    156.4900
# 1258    163.0300
# Name: apple_close, Length: 1259, dtype: float64

# %%
 (closing_price['apple_close'] - closing_price['apple_close'].shift(1))/closing_price['apple_close'].shift(1)*100
# Out:
# 0            NaN
# 1       1.042235
# 2      -2.506658
# 3      -0.190297
# 4      -0.089934
#           ...
# 1254    0.209043
# 1255   -4.339015
# 1256   -2.498442
# 1257    4.179181
# 1258   -2.140710
# Name: apple_close, Length: 1259, dtype: float64

# %%
for col in closing_price.columns:
     closing_price[col+'_pct_change'] = (closing_price[col] - closing_price[col].shift(1))/closing_price[col].shift(1)*100

# %%
closing_price
# Out:
#       apple_close  amazon_close  google_close  msft_close  \
# 0         67.8542        261.95        558.46       27.55
# 1         68.5614        257.21        559.99       27.86
# 2         66.8428        258.70        556.97       27.88
# 3         66.7156        269.47        567.16       28.03
# 4         66.6556        269.24        567.00       28.04
# ...           ...           ...           ...         ...
# 1254     167.7800       1390.00           NaN       94.26
# 1255     160.5000       1429.95           NaN       91.78
# 1256     156.4900       1390.00           NaN       88.00
# 1257     163.0300       1442.84           NaN       91.33
# 1258     159.5400       1416.78           NaN       89.61
#
#       apple_close_pct_change  amazon_close_pct_change  \
# 0                        NaN                      NaN
# 1                   1.042235                -1.809506
# 2                  -2.506658                 0.579293
# ...

# %%
closing_price.columns
# Out:
# Index(['apple_close', 'amazon_close', 'google_close', 'msft_close',
#        'apple_close_pct_change', 'amazon_close_pct_change',
#        'google_close_pct_change', 'msft_close_pct_change'],
#       dtype='object')

# %%
cls_p = closing_price[['apple_close_pct_change', 'amazon_close_pct_change',
       'google_close_pct_change', 'msft_close_pct_change']]

# %%
cls_p
# Out:
#       apple_close_pct_change  amazon_close_pct_change  \
# 0                        NaN                      NaN
# 1                   1.042235                -1.809506
# 2                  -2.506658                 0.579293
# 3                  -0.190297                 4.163123
# 4                  -0.089934                -0.085353
# ...                      ...                      ...
# 1254                0.209043                -4.196734
# 1255               -4.339015                 2.874101
# 1256               -2.498442                -2.793804
# 1257                4.179181                 3.801439
# 1258               -2.140710                -1.806160
#
#       google_close_pct_change  msft_close_pct_change
# 0                         NaN                    NaN
# 1                    0.273968               1.125227
# 2                   -0.539295               0.071788
# 3                    1.829542               0.538020
# ...

# %%
g = sns.PairGrid(data=cls_p)
g.map_diag(sns.histplot)
g.map_lower(sns.scatterplot)
g.map_upper(sns.kdeplot)

# %%
cls_p.corr()
# Out:
#                          apple_close_pct_change  amazon_close_pct_change  \
# apple_close_pct_change                 1.000000                 0.287659
# amazon_close_pct_change                0.287659                 1.000000
# google_close_pct_change                0.036202                 0.027698
# msft_close_pct_change                  0.366598                 0.402678
#
#                          google_close_pct_change  msft_close_pct_change
# apple_close_pct_change                  0.036202               0.366598
# amazon_close_pct_change                 0.027698               0.402678
# google_close_pct_change                 1.000000               0.038939
# msft_close_pct_change                   0.038939               1.000000

# %%
print("if there is a decrease in Amazon price, thers is a 40% probabilility that Microsoft price will also decrease")
# Out:
# if there is a decrease in Amazon price, thers is a 40% probabilility that Microsoft price will also decrease
